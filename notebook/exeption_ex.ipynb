# %%
import traceback
import sys

def func_a():
    func_b()

def func_b():
    1 / 0  # This will raise ZeroDivisionError

try:
    func_a()
except Exception as e:
    tb = e.__traceback__
    traceback.print_tb(tb)
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_20144\1780608910.py", line 11, in <module>
#     func_a()
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_20144\1780608910.py", line 5, in func_a
#     func_b()
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_20144\1780608910.py", line 8, in func_b
#     1 / 0  # This will raise ZeroDivisionError
